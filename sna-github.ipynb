# %% [markdown]
# ## Análise da Rede Social do GitHub
# dataset: https://snap.stanford.edu/data/github-social.html<br>
#
# Isabel de Castro Cordeiro, <br>
# Email: icastrocordeiro@gmail.com<br>
# LinkedIn: https://www.linkedin.com/in/isabel-castroc/<br>
# Universidade Federal do Ceará, Fortaleza, Brasil.

# %%
! pip3 install torch_geometric
! pip3 install torch_sparse
! pip3 install torch_scatter
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.0.3.tar.gz (370 kB)
#      |████████████████████████████████| 370 kB 4.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (4.62.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (2.6.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (1.3.5)
# Collecting rdflib
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 31.1 MB/s
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (2.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (3.0.7)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from torch_geometric) (3.13)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch_geometric) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch_geometric) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch_geometric) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch_geometric) (1.15.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 223 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch_geometric) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib->torch_geometric) (4.10.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib->torch_geometric) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib->torch_geometric) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch_geometric) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch_geometric) (1.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.3-py3-none-any.whl size=581968 sha256=3976376dfac3a103969f5d5d5fbc2b110027899982ab3b2580d49b9abde363e9
#   Stored in directory: /root/.cache/pip/wheels/c3/2a/58/87ce0508964d4def1aafb92750c4f3ac77038efd1b9a89dcf5
# Successfully built torch-geometric
# Installing collected packages: isodate, yacs, rdflib, torch-geometric
# Successfully installed isodate-0.6.1 rdflib-6.1.1 torch-geometric-2.0.3 yacs-0.1.8
# Collecting torch_sparse
#   Downloading torch_sparse-0.6.12.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 816 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch_sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch_sparse) (1.19.5)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... done
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.12-cp37-cp37m-linux_x86_64.whl size=505740 sha256=4f3cf51a42f485d1781eded7a3e505eddf2f8909460e5dd2a24762bb7bc676cb
#   Stored in directory: /root/.cache/pip/wheels/fb/e2/2f/44956c61e3299573ffe12da9d1374c7576ca0c5fb1fe1ed38c
# Successfully built torch-sparse
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.12
# Collecting torch_scatter
#   Downloading torch_scatter-2.0.9.tar.gz (21 kB)
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=282116 sha256=91a0398a9f22cf119128fb845dcf35a326134d3e1615208a7b4a9427930c2a88
#   Stored in directory: /root/.cache/pip/wheels/dd/57/a3/42ea193b77378ce634eb9454c9bc1e3163f3b482a35cdee4d1
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9

# %%
import json
import collections
import numpy as np
import pandas as pd
import math as math
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.data import Data
from torch_geometric.transforms import RandomNodeSplit as masking
from torch_geometric.utils.convert import to_networkx
from torch_geometric.nn import GCNConv

# %% [markdown]
# ### Pré-processamento dos Dados

# %%
with open("data/musae_git_features.json") as json_data:
    data_raw = json.load(json_data)
    
target = pd.read_csv("data/musae_git_target.csv")
edges = pd.read_csv("data/musae_git_edges.csv")

# %%
target.head()
# Out:
#    id          name  ml_target
# 0   0        Eiryyy          0
# 1   1    shawflying          0
# 2   2   JpMCarrilho          1
# 3   3     SuhwanCha          0
# 4   4  sunilangadi2          1

# %%
target.shape
# Out:
# (37700, 3)

# %%
target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37700 entries, 0 to 37699
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         37700 non-null  int64
#  1   name       37700 non-null  object
#  2   ml_target  37700 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 883.7+ KB

# %%
target['ml_target'].value_counts()
# Out:
# 0    27961
# 1     9739
# Name: ml_target, dtype: int64

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7,5))
plt.title('Quantidade de desenvolvedores por classe')
sns.countplot(x="ml_target", color = 'orange', data=target)
plt.show()

# %%
plt.title('Proporção de desenvolvedores por classe')
target.ml_target.value_counts().plot(kind='pie',colors = ('r','b'), autopct='%.1f%%',figsize=(6,6))
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Estrutura da Rede
#
# Aqui avaliamos a estrutura da rede a partir do arquivo que contém a lista de arestas.

# %%
edges.head()
# Out:
#    id_1   id_2
# 0     0  23977
# 1     1  34526
# 2     1   2370
# 3     1  14683
# 4     1  29982

# %%
edges.shape
# Out:
# (289003, 2)

# %%
edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289003 entries, 0 to 289002
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id_1    289003 non-null  int64
#  1   id_2    289003 non-null  int64
# dtypes: int64(2)
# memory usage: 4.4 MB

# %% [markdown]
# A densidade $D$ de uma rede é definida como uma relação entre o número de arestas $E$ para o número de arestas possíveis, dada por
# $ D = \frac{2E}{N(N-1)}$

# %%
G = nx.read_edgelist("data/musae_git_edges.txt", nodetype = int)
print(nx.info(G))
print("Density:", "%3.4f"%nx.density(G))
# Out:
# Graph with 37700 nodes and 289003 edges
# Density: 0.0004

# %%
pos = nx.spring_layout(G)
plt.rcParams['figure.figsize'] = (20, 15)
plt.axis('off')

nx.draw(G, pos, node_color = "blue", node_size = 20, with_labels = False)
plt.savefig("graph.png")

# %% [markdown]
# ### Medidas relacionadas ao grau
#
# O grau $k$ de um nó é o número de arestas conectadas a ele.
#
# O grau médio da rede:

# %%
vk = dict(G.degree())
vk = dict(sorted(vk.items()))
vk = list(vk.values())
vk = np.array(vk)
print(vk)

md = np.mean(vk)
print('Mean degree: ', "%3.4f"%md)
# Out:
# [1 8 1 ... 4 3 4]
# Mean degree:  15.3317

# %% [markdown]
# A partir dos graus dos nós, podemos calcular várias medidas estatísticas. Desenvolvemos uma função para calcular a distribuição de graus e representamos graficamente a distribuição de graus em escala log-log.

# %%
def degree_distribution(G):
    vk = dict(G.degree())
    vk = dict(sorted(vk.items()))
    vk = list(vk.values())  # we get only the degree values
    vk = np.array(vk)
    maxk = np.max(vk)
    mink = np.min(vk)
    kvalues= np.arange(0,maxk+1) # possible values of k
    Pk = np.zeros(maxk+1) # P(k)
    for k in vk:
        Pk[k] = Pk[k] + 1
    Pk = Pk/sum(Pk) # the sum of the elements of P(k) must to be equal to one
    return kvalues,Pk

ks, Pk = degree_distribution(G)

plt.figure(figsize=(7,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(ks,Pk,'o',color = 'crimson')
plt.xlabel("k")
plt.ylabel("P(k)")
plt.title("Degree distribution")
plt.grid(False)
plt.show()

# %% [markdown]
# O nível de heterogeneidade da rede em relação ao número de conexões pode ser quantificado pela entropia de Shannon. Uma função para calcular a entropia de Shannon da distribuição de graus pode ser definida como:

# %%
def shannon_entropy(G):
    k,Pk = degree_distribution(G)
    H = 0
    for p in Pk:
        if(p > 0):
            H = H - p*math.log(p, 2)
    return H

H = shannon_entropy(G)
print("Shannon Entropy = ", "%3.4f"%H)
# Out:
# Shannon Entropy =  4.8587

# %% [markdown]
# ### Coeficiente de clusterização
#
# O coeficiente de agregação é uma medida de propriedade "all-my-friends-know-each-other". Isso é algumas vezes descrito como os amigos dos meus amigos são meus amigos. Mais precisamente, o coeficiente de agregação de um nó é o rácio entre os ligações existentes conectando os vizinhos do nó uns aos outros para o maior número possível de tais ligações. O coeficiente de agregação para toda a rede é a média dos coeficientes de todos os nós de agregação.

# %%
avc = nx.average_clustering(G)
print("Average clustering:", "%3.4f"%avc)
# Out:
# Average clustering: 0.1675

# %% [markdown]
# O agrupamento de cada nó é definido pela fração de arestas entre os vizinhos de cada nó.<br>
# Isto é, o coeficiente de agregação do nó $i$ é $C_i = \frac{2e_i}{k_i (k_i-1)}$, onde $k_i$ é o número de vizinhos do nó $i$, e $e_i$ é o número de conexões entre esses vizinhos. O maior número possível de conexões entre vizinhos é, naturalmente, $\frac{k(k-1)}{2}$.

# %%
vcc = []
for i in sorted(G.nodes()):
    vcc.append(nx.clustering(G, i))
vcc = np.array(vcc)
print('Clustering of all nodes:', vcc)
# Out:
# Clustering of all nodes: [0.         0.17857143 0.         ... 0.         0.         0.33333333]

# %%
plt.figure(figsize=(7,5))
plt.hist(vcc, bins = 10, color = 'darkcyan')
plt.title("Distribution of the clustering coefficient")
plt.ylabel("P(cc)")
plt.xlabel("Clustering coefficient (cc)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Diâmetro
#
# Como outro meio de medir grafos de rede, podemos definir o diâmetro de uma rede como o mais longo de todos os caminhos mais curtos calculados numa rede. Por outras palavras, uma vez que o menor comprimento do caminho de cada nó para todos os outros nós é calculado, o diâmetro é o mais longo de todos os comprimentos do caminho calculado. O diâmetro é representante do tamanho de uma rede.

# %%
d = nx.diameter(G)
print('Network diameter:', d)
# Out:
# Network diameter: 11

# %% [markdown]
# Outra medida relacionada às distâncias é a eficiência da rede, que é uma medida da eficiência das trocas de informações da rede. A eficiência global média de um gráfico é a eficiência média de todos os pares de nós. Quanto maior for essa medida, melhor será a transmissão de informações em uma rede.

# %%
E = nx.global_efficiency(G)
print('Network efficiency', "%3.4f"%E)
# Out:
# Network efficiency 0.3259

# %% [markdown]
# ### Centralidade
# Informações sobre a importância relativa de nós e arestas num grafo podem ser obtidas através de medidas de centralidade. A centralidade de um nó pode ser vista como uma medida da influência ou importância num modelo de rede. O objetivo da análise da rede geralmente determina o tipo de centralidades a ser usado.
#
# **Closeness centrality**
#
# Em um gráfico conectado, a *centralidade de proximidade* (ou proximidade) de um nó é uma medida de centralidade em uma rede, calculada como o recíproco da soma do comprimento dos caminhos mais curtos entre o nó e todos os outros nós no gráfico. Assim, quanto mais central um nó, mais próximo ele está de todos os outros nós.

# %%
CLC = dict(nx.closeness_centrality(G))
CLC = dict(sorted(CLC.items()))

# %%
CLC = list(CLC.values())
av_clc = np.mean(CLC)
print('Average closeness centrality', "%3.4f"%av_clc)
# Out:
# Average closeness centrality 0.3137

# %%
plt.figure(figsize=(7,5))
plt.hist(CLC, color = 'darkcyan')
plt.title("Distribution of the Closeness Centrality")
plt.ylabel("P(CLC)")
plt.xlabel("Closeness Centrality (CLC)")
plt.show(True)

# %% [markdown]
# ### Exploração dos Atributos

# %%
i = 0
for key,value in data_raw.items():
      print(key, value)
      i+=1
      if i == 10:
        break
# Out:
# 0 [1574, 3773, 3571, 2672, 2478, 2534, 3129, 3077, 1171, 2045, 1539, 902, 1532, 2472, 1122, 2480, 3098, 2115, 1578]
# 1 [1193, 376, 73, 290, 3129, 1852, 3077, 1171, 1022, 2045, 536, 2040, 1533, 1532, 2472, 673, 798]
# 2 [1574, 3773, 925, 1728, 2815, 2963, 3077, 364, 1171, 536, 1867, 2472, 1122, 2532, 664, 28, 3311, 1768, 869]
# 3 [3964, 3773, 4003, 928, 1852, 3077, 364, 1022, 3763, 2045, 3859, 3771, 234, 664, 703]
# 4 [1929, 3773, 1793, 3511, 1290, 3129, 3077, 364, 1171, 1022, 2045, 536, 1119, 91, 1532, 3771, 1122, 703, 1001]
# 5 [1574, 3773, 1793, 2934, 1088, 2465, 1618, 1233, 2282, 2947, 2211, 1087, 3129, 1852, 3077, 1171, 3763, 2045, 536, 137, 3849, 1532, 2472, 2371, 2266, 703]
# 6 [3964, 509, 3214, 581, 364, 1171, 1022, 3763, 2045, 1366, 1532, 2472, 3794, 3711]
# 7 [1193, 1249, 1663, 819, 1171, 1022, 2045, 1026, 2311, 1532, 2472, 3794, 664, 703]
# 8 [1193, 1051, 3571, 3129, 1171, 3763, 2045, 536, 128, 1532, 3771, 2371, 2749, 3827, 2602]
# 9 [2657, 1360, 1793, 1290, 3129, 1852, 364, 1022, 2045, 536, 1927, 3375, 1532, 3771, 1348, 1606]

# %%
feats=[]
feat_counts=[]
for i in range(len(data_raw)):
    feat_counts+=[len(data_raw[str(i)])]
    feats+=data_raw[str(i)]
    
print("Número de atributos:",max(feats)+1)
# Out:
# Número de atributos: 4005

# %%
plt.figure(figsize=(7,5))
plt.hist(feat_counts, bins = 20, color = 'darkviolet')
plt.title("Number of features per graph distribution")
plt.show()

plt.figure(figsize=(7,5))
plt.hist(feats, bins = 40, color = 'darkviolet')
plt.title("Features distribution")
plt.show()

# %% [markdown]
# Os atributos dos nós nos dizem qual recurso está anexado a cada nó. É possível codificar esses recursos atributos na função `encode_data`. O objetivo é usar essa função para codificar um subconjunto leve do gráfico (por exemplo, apenas 60 nós) para fins de visualização.

# %%
def encode_data(light=False,n=60):
    if light==True:
        nodes_included=n
    elif light==False:
        nodes_included=len(data_raw)
    data_encoded={}
    for i in range(nodes_included):# 
        one_hot_feat=np.array([0]*(max(feats)+1))
        this_feat=data_raw[str(i)]
        one_hot_feat[this_feat]=1
        data_encoded[str(i)]=list(one_hot_feat)
    if light==True:
        sparse_feat_matrix=np.zeros((1,max(feats)+1))
        for j in range(nodes_included):
            temp=np.array(data_encoded[str(j)]).reshape(1,-1)
            sparse_feat_matrix=np.concatenate((sparse_feat_matrix,temp),axis=0)
        sparse_feat_matrix=sparse_feat_matrix[1:,:]
        return(data_encoded,sparse_feat_matrix)
    elif light==False:
        return(data_encoded, None)

# %% [markdown]
# Podemos plotar as primeiras 250 colunas de atributos (o total é 4005) do código para os primeiros 60 usuários. Abaixo, podemos visualizar o quão esparsa é a matriz que construímos para os atributos dos nós.

# %%
data_encoded_vis,sparse_feat_matrix_vis=encode_data(light=True,n=60)
plt.figure(figsize=(25,25))
plt.imshow(sparse_feat_matrix_vis[:,:250],cmap='Greys')
plt.show()

# %% [markdown]
# Para construir o grafo, usamos o `torch_geometric.data.Data`, que é um objeto Python simples para modelar um único grafo com vários atributos (opcionais). Construimos o grafo usando esta classe e passando os seguintes atributos:
#
# - **x**: será atribuído aos recursos do nó codificado, seu formato é `[número_de_nós, número_de_características]`.
#
# - **y**: será atribuído aos rótulos dos nós, sua forma é `[número_de_nós] `
#
# - **edge_index**: para representar um grafo não direcionado, precisamos estender os índices das arestas originais de uma forma que possamos ter duas arestas direcionadas separadas conectando os mesmos dois nós, mas apontando na direção oposta um ao outro. Esta é uma maneira de representar o grafo não direcionado se tivermos os índices das arestas. A forma do tensor será `[2,2 * number_of_original_edges]`.

# %%
def construct_graph(data_encoded,light=False):
    node_features_list=list(data_encoded.values())
    node_features=torch.tensor(node_features_list)
    node_labels=torch.tensor(target['ml_target'].values)
    edges_list=edges.values.tolist()
    edge_index01=torch.tensor(edges_list, dtype = torch.long).T
    edge_index02=torch.zeros(edge_index01.shape, dtype = torch.long)#.T
    edge_index02[0,:]=edge_index01[1,:]
    edge_index02[1,:]=edge_index01[0,:]
    edge_index0=torch.cat((edge_index01,edge_index02),axis=1)
    g = Data(x=node_features, y=node_labels, edge_index=edge_index0)
    g_light = Data(x=node_features[:,0:2],
                     y=node_labels   ,
                     edge_index=edge_index0[:,:55])
    if light:
        return(g_light)
    else:
        return(g)

# %% [markdown]
# Para desenhar um grafo, temos a função `draw_graph`.

# %%
def draw_graph(data0):
    #node_labels=data0.y
    if data0.num_nodes>100:
        print("This is a big graph, can not plot...")
        return
    else:
        data_nx = to_networkx(data0)
        node_colors=data0.y[list(data_nx.nodes)]
        pos= nx.spring_layout(data_nx,scale =1)
        plt.figure(figsize=(12,8))
        nx.draw(data_nx, pos,  cmap=plt.get_cmap('Set1'),
                node_color=node_colors,node_size=400,connectionstyle="angle3",
                width=1, with_labels = False, edge_color = 'k', arrowstyle = "-")

# %% [markdown]
# Agora, é possível desenhar um subgrafo chamando` construct_graph `com `light=True.` Então podemos passá-lo para `draw_graph`, para mostrar o grafo a seguir. Pode-se ver como os nós são conectados por arestas e rotulados por cores.

# %%
g_sample=construct_graph(data_encoded=data_encoded_vis,light=True)
draw_graph(g_sample)

# %% [markdown]
# ### Construção e treinamento do modelo GNN

# %% [markdown]
# Começamos codificando todos os dados chamando `encode_data` com `light=False` e construímos o grafo completo chamando `construct_graph` com `light=False`. A visualização completa desse grafo pode ser encontrada nas células acima.

# %%
data_encoded,_=encode_data(light=False)
g=construct_graph(data_encoded=data_encoded,light=False)

# %% [markdown]
# A etapa imediata após a preparação dos dados para o modelo é a divisão dos dados em subconjuntos para treinar o modelo e validar o seu desempenho em relação aos novos, e por último um segmento de teste para relatar o desempenho geral.
#
# A divisão de um grafo não é direta, pois temos um único grafo muito grande. Para indicar na fase de treinamento quais nós devem ser incluídos para treinamento e na fase de inferência quais nós farão parte dos dados de teste, é possível utilizar máscaras que são vetores binários que indicam (usando 0 e 1) quais nós pertencem a cada máscara em particular.
#
# A classe `torch_geometric.transforms.AddTrainValTestMask` pega nosso grafo e define como queremos que nossas máscaras sejam formadas e adiciona uma divisão de nível de nó por meio dos atributos `train_mask`,` val_mask` e `test_mask`.

# %% [markdown]
# No treinamento, usamos 30% como conjunto de validação e 30% como conjunto de teste enquanto mantemos apenas 40% para o treinamento.
#
# Também podemos imprimir as informações do grafo e o número de nós de cada conjunto (máscara). Os números entre colchetes são a forma de cada tensor de atributo.

# %%
msk=masking(split="train_rest", num_splits = 1, num_val = 0.3, num_test= 0.3)
g=msk(g)
print(g)
print()
print("training samples",torch.sum(g.train_mask).item())
print("validation samples",torch.sum(g.val_mask ).item())
print("test samples",torch.sum(g.test_mask ).item())
# Out:
# Data(x=[37700, 4005], edge_index=[2, 578006], y=[37700], train_mask=[37700], val_mask=[37700], test_mask=[37700])
#
# training samples 15080
# validation samples 11310
# test samples 11310

# %% [markdown]
# Nesse ponto, podemos construir a classe modelo GNN. Para isso, será usada a classe `torch_geometric.nn.GCNConv`.
#
# Empilharemos duas camadas GCNConv, a primeira tem entrada igual ao número de atributos do grafo e algum número arbitrário de features de saída `f`. Em seguida, aplicamos uma função de ativação `leaky_relu` e entregamos os recursos latentes à segunda camada, que tem nós de saída iguais ao número de classes (ou seja, 2).

# %%
class SocialGNN(torch.nn.Module):
    def __init__(self,num_of_feat,f):
        super(SocialGNN, self).__init__()
        self.conv1 = GCNConv(num_of_feat, f)
        self.conv2 = GCNConv(f, 2)
    def forward(self, data):
        x = data.x.float()
        edge_index =  data.edge_index
        x = self.conv1(x=x, edge_index=edge_index)
        x = F.leaky_relu(x)
        x = self.conv2(x, edge_index)
        return x

# %% [markdown]
# Como o modelo irá prever a classe de todos os vértices do grafo, nós, no entanto, queremos calcular a perda e a precisão para um conjunto específico com base na fase em que estamos. Por exemplo, durante o treinamento, queremos calcular a perda e a precisão do treinamento apenas com base no conjunto de treinamento e é aqui onde devemos usar as máscaras. Vamos definir as funções `masked_loss` e `masked_accuracy` para as quais passamos as respectivas máscaras e as mesmas retornam a perda e a precisão correspondentes. A ideia é calcular a perda e a precisão de todos os nós e multiplicá-los pela máscara para zerar os nós não necessários.

# %%
def masked_loss(predictions,labels,mask):
    mask=mask.float()
    mask=mask/torch.mean(mask)
    loss=criterion(predictions,labels)
    loss=loss*mask
    loss=torch.mean(loss)
    return (loss)    
def masked_accuracy(predictions,labels,mask):
    mask=mask.float()
    mask/=torch.mean(mask)
    accuracy=(torch.argmax(predictions,axis=1)==labels).long()
    accuracy=mask*accuracy
    accuracy=torch.mean(accuracy)
    return (accuracy)

# %% [markdown]
# Aqui, podemos definir nossa função de treinamento na qual usaremos o otimizador `torch.optim.Adam`. Executaremos o treinamento por um certo número de épocas e acompanharemos para obter a melhor precisão de validação. Também representamos as perdas e as precisões ao longo das épocas do treinamento.

# %%
def train_social(net,data,epochs=10,lr=0.01):
    optimizer = torch.optim.Adam(net.parameters(), lr=lr) # 00001
    best_accuracy=0.0
    train_losses=[]
    train_accuracies=[]
    val_losses=[]
    val_accuracies=[]
    test_losses=[]
    test_accuracies=[]
    for ep in range(epochs+1):
        optimizer.zero_grad()
        out=net(data)
        loss=masked_loss(predictions=out,
                         labels=data.y,
                         mask=data.train_mask)
        loss.backward()
        optimizer.step()
        train_losses+=[loss]
        train_accuracy=masked_accuracy(predictions=out,
                                       labels=data.y, 
                                       mask=data.train_mask)
        train_accuracies+=[train_accuracy]
        val_loss=masked_loss(predictions=out,
                             labels=data.y, 
                             mask=data.val_mask)
        val_losses+=[val_loss]
        val_accuracy=masked_accuracy(predictions=out,
                                     labels=data.y, 
                                     mask=data.val_mask)
        val_accuracies+=[val_accuracy]
        test_accuracy=masked_accuracy(predictions=out,
                                      labels=data.y, 
                                      mask=data.test_mask)
        test_accuracies+=[test_accuracy]
        if np.round(val_accuracy,4)> np.round(best_accuracy ,4):
            print("Epoch {}/{}, Train_Loss: {:.4f}, Train_Accuracy: {:.4f}, Val_Accuracy: {:.4f}, Test_Accuracy: {:.4f}"
                      .format(ep+1,epochs, loss.item(), train_accuracy, val_accuracy,  test_accuracy))
            best_accuracy=val_accuracy
    plt.figure(figsize=(12,8))
    plt.plot(train_losses)
    plt.plot(val_losses)
    plt.plot(test_losses)
    plt.legend(['Train_Loss','Val_Loss','Test_Loss'])
    plt.show()
    plt.figure(figsize=(12,8))
    plt.plot(train_accuracies,label='Train_Accuracy') 
    plt.plot(val_accuracies,label='Val_Accuracy')
    plt.plot(test_accuracies,label='Test_Accuracy')
    plt.legend(['Train_Accuracy','Val_Accuracy','Test_Accuracy'])
    plt.show()

# %% [markdown]
# Neste ponto, temos todas as funções necessárias e estamos prontos para instanciar nosso modelo e treiná-lo. Construiremos o modelo com 16 filtros e usaremos `nn.CrossEntropyLoss` como nosso critério de perda. Por fim, podemos ver que nosso modelo simples atingiu uma precisão muito decente no conjunto de teste, mais de 91%. Também podemos ver as curvas de aprendizagem (perdas) e o desenvolvimento de acurácias ao longo das épocas nos gráficos superior e inferior, respectivamente

# %%
num_of_feat=g.num_node_features
net=SocialGNN(num_of_feat=num_of_feat,f=12)
criterion=nn.CrossEntropyLoss()
train_social(net,g,epochs=200,lr=0.1)
# Out:
# Epoch 1/200, Train_Loss: 0.7173, Train_Accuracy: 0.2579, Val_Accuracy: 0.2669, Test_Accuracy: 0.2544
# Epoch 2/200, Train_Loss: 1.0803, Train_Accuracy: 0.7434, Val_Accuracy: 0.7346, Test_Accuracy: 0.7464
# Epoch 3/200, Train_Loss: 0.5020, Train_Accuracy: 0.7436, Val_Accuracy: 0.7347, Test_Accuracy: 0.7464
# Epoch 16/200, Train_Loss: 0.4060, Train_Accuracy: 0.8246, Val_Accuracy: 0.8238, Test_Accuracy: 0.8299
# Epoch 17/200, Train_Loss: 0.4082, Train_Accuracy: 0.8427, Val_Accuracy: 0.8433, Test_Accuracy: 0.8497
# Epoch 18/200, Train_Loss: 0.4015, Train_Accuracy: 0.8485, Val_Accuracy: 0.8514, Test_Accuracy: 0.8559
# Epoch 19/200, Train_Loss: 0.3863, Train_Accuracy: 0.8501, Val_Accuracy: 0.8531, Test_Accuracy: 0.8582
# Epoch 24/200, Train_Loss: 0.3584, Train_Accuracy: 0.8542, Val_Accuracy: 0.8533, Test_Accuracy: 0.8608
# Epoch 25/200, Train_Loss: 0.3478, Train_Accuracy: 0.8603, Val_Accuracy: 0.8599, Test_Accuracy: 0.8664
# Epoch 26/200, Train_Loss: 0.3394, Train_Accuracy: 0.8649, Val_Accuracy: 0.8662, Test_Accuracy: 0.8701
# Epoch 27/200, Train_Loss: 0.3373, Train_Accuracy: 0.8674, Val_Accuracy: 0.8664, Test_Accuracy: 0.8715
# Epoch 30/200, Train_Loss: 0.3283, Train_Accuracy: 0.8678, Val_Accuracy: 0.8679, Test_Accuracy: 0.8714
# Epoch 32/200, Train_Loss: 0.3227, Train_Accuracy: 0.8712, Val_Accuracy: 0.8688, Test_Accuracy: 0.8729
# Epoch 33/200, Train_Loss: 0.3236, Train_Accuracy: 0.8707, Val_Accuracy: 0.8699, Test_Accuracy: 0.8743
# Epoch 34/200, Train_Loss: 0.3216, Train_Accuracy: 0.8718, Val_Accuracy: 0.8706, Test_Accuracy: 0.8747
# Epoch 35/200, Train_Loss: 0.3173, Train_Accuracy: 0.8718, Val_Accuracy: 0.8707, Test_Accuracy: 0.8738
# Epoch 41/200, Train_Loss: 0.3103, Train_Accuracy: 0.8742, Val_Accuracy: 0.8721, Test_Accuracy: 0.8764
# Epoch 43/200, Train_Loss: 0.3091, Train_Accuracy: 0.8747, Val_Accuracy: 0.8723, Test_Accuracy: 0.8776
# Epoch 44/200, Train_Loss: 0.3067, Train_Accuracy: 0.8754, Val_Accuracy: 0.8728, Test_Accuracy: 0.8775
# Epoch 48/200, Train_Loss: 0.3022, Train_Accuracy: 0.8771, Val_Accuracy: 0.8735, Test_Accuracy: 0.8794
# Epoch 49/200, Train_Loss: 0.3010, Train_Accuracy: 0.8772, Val_Accuracy: 0.8754, Test_Accuracy: 0.8805
# Epoch 50/200, Train_Loss: 0.3005, Train_Accuracy: 0.8778, Val_Accuracy: 0.8760, Test_Accuracy: 0.8810
# Epoch 51/200, Train_Loss: 0.2993, Train_Accuracy: 0.8781, Val_Accuracy: 0.8765, Test_Accuracy: 0.8819
# Epoch 52/200, Train_Loss: 0.2974, Train_Accuracy: 0.8786, Val_Accuracy: 0.8772, Test_Accuracy: 0.8821
# Epoch 55/200, Train_Loss: 0.2945, Train_Accuracy: 0.8822, Val_Accuracy: 0.8778, Test_Accuracy: 0.8834
# Epoch 56/200, Train_Loss: 0.2933, Train_Accuracy: 0.8816, Val_Accuracy: 0.8794, Test_Accuracy: 0.8842
# Epoch 57/200, Train_Loss: 0.2927, Train_Accuracy: 0.8804, Val_Accuracy: 0.8801, Test_Accuracy: 0.8843
# Epoch 58/200, Train_Loss: 0.2922, Train_Accuracy: 0.8808, Val_Accuracy: 0.8805, Test_Accuracy: 0.8848
# Epoch 59/200, Train_Loss: 0.2913, Train_Accuracy: 0.8813, Val_Accuracy: 0.8808, Test_Accuracy: 0.8850
# Epoch 63/200, Train_Loss: 0.2878, Train_Accuracy: 0.8840, Val_Accuracy: 0.8810, Test_Accuracy: 0.8864
# Epoch 64/200, Train_Loss: 0.2869, Train_Accuracy: 0.8836, Val_Accuracy: 0.8819, Test_Accuracy: 0.8883
# Epoch 65/200, Train_Loss: 0.2862, Train_Accuracy: 0.8832, Val_Accuracy: 0.8827, Test_Accuracy: 0.8879
# Epoch 66/200, Train_Loss: 0.2854, Train_Accuracy: 0.8835, Val_Accuracy: 0.8828, Test_Accuracy: 0.8888
# Epoch 71/200, Train_Loss: 0.2819, Train_Accuracy: 0.8851, Val_Accuracy: 0.8831, Test_Accuracy: 0.8904
# Epoch 72/200, Train_Loss: 0.2813, Train_Accuracy: 0.8859, Val_Accuracy: 0.8835, Test_Accuracy: 0.8910
# Epoch 73/200, Train_Loss: 0.2805, Train_Accuracy: 0.8858, Val_Accuracy: 0.8836, Test_Accuracy: 0.8910
# Epoch 76/200, Train_Loss: 0.2784, Train_Accuracy: 0.8871, Val_Accuracy: 0.8837, Test_Accuracy: 0.8916
# Epoch 77/200, Train_Loss: 0.2777, Train_Accuracy: 0.8873, Val_Accuracy: 0.8846, Test_Accuracy: 0.8920
# Epoch 83/200, Train_Loss: 0.2738, Train_Accuracy: 0.8893, Val_Accuracy: 0.8848, Test_Accuracy: 0.8929
# Epoch 84/200, Train_Loss: 0.2732, Train_Accuracy: 0.8897, Val_Accuracy: 0.8849, Test_Accuracy: 0.8926
# Epoch 85/200, Train_Loss: 0.2726, Train_Accuracy: 0.8901, Val_Accuracy: 0.8850, Test_Accuracy: 0.8929
# Epoch 86/200, Train_Loss: 0.2719, Train_Accuracy: 0.8906, Val_Accuracy: 0.8851, Test_Accuracy: 0.8936
# Epoch 87/200, Train_Loss: 0.2713, Train_Accuracy: 0.8908, Val_Accuracy: 0.8852, Test_Accuracy: 0.8948
# Epoch 88/200, Train_Loss: 0.2707, Train_Accuracy: 0.8910, Val_Accuracy: 0.8856, Test_Accuracy: 0.8955
# Epoch 89/200, Train_Loss: 0.2700, Train_Accuracy: 0.8910, Val_Accuracy: 0.8861, Test_Accuracy: 0.8950
# Epoch 90/200, Train_Loss: 0.2695, Train_Accuracy: 0.8912, Val_Accuracy: 0.8863, Test_Accuracy: 0.8952
# Epoch 91/200, Train_Loss: 0.2689, Train_Accuracy: 0.8912, Val_Accuracy: 0.8868, Test_Accuracy: 0.8953
# Epoch 93/200, Train_Loss: 0.2677, Train_Accuracy: 0.8924, Val_Accuracy: 0.8869, Test_Accuracy: 0.8958
# Epoch 94/200, Train_Loss: 0.2671, Train_Accuracy: 0.8919, Val_Accuracy: 0.8874, Test_Accuracy: 0.8959
# Epoch 95/200, Train_Loss: 0.2665, Train_Accuracy: 0.8928, Val_Accuracy: 0.8882, Test_Accuracy: 0.8964
# Epoch 96/200, Train_Loss: 0.2660, Train_Accuracy: 0.8929, Val_Accuracy: 0.8886, Test_Accuracy: 0.8966
# Epoch 97/200, Train_Loss: 0.2654, Train_Accuracy: 0.8934, Val_Accuracy: 0.8889, Test_Accuracy: 0.8964
# Epoch 98/200, Train_Loss: 0.2648, Train_Accuracy: 0.8937, Val_Accuracy: 0.8897, Test_Accuracy: 0.8968
# Epoch 99/200, Train_Loss: 0.2643, Train_Accuracy: 0.8942, Val_Accuracy: 0.8901, Test_Accuracy: 0.8965
# Epoch 100/200, Train_Loss: 0.2637, Train_Accuracy: 0.8940, Val_Accuracy: 0.8906, Test_Accuracy: 0.8972
# Epoch 101/200, Train_Loss: 0.2632, Train_Accuracy: 0.8944, Val_Accuracy: 0.8910, Test_Accuracy: 0.8975
# Epoch 102/200, Train_Loss: 0.2626, Train_Accuracy: 0.8948, Val_Accuracy: 0.8912, Test_Accuracy: 0.8980
# Epoch 103/200, Train_Loss: 0.2621, Train_Accuracy: 0.8953, Val_Accuracy: 0.8917, Test_Accuracy: 0.8985
# Epoch 104/200, Train_Loss: 0.2615, Train_Accuracy: 0.8951, Val_Accuracy: 0.8921, Test_Accuracy: 0.8989
# Epoch 108/200, Train_Loss: 0.2594, Train_Accuracy: 0.8957, Val_Accuracy: 0.8924, Test_Accuracy: 0.8999
# Epoch 109/200, Train_Loss: 0.2589, Train_Accuracy: 0.8956, Val_Accuracy: 0.8927, Test_Accuracy: 0.9002
# Epoch 110/200, Train_Loss: 0.2584, Train_Accuracy: 0.8957, Val_Accuracy: 0.8929, Test_Accuracy: 0.8999
# Epoch 111/200, Train_Loss: 0.2579, Train_Accuracy: 0.8958, Val_Accuracy: 0.8932, Test_Accuracy: 0.9000
# Epoch 112/200, Train_Loss: 0.2574, Train_Accuracy: 0.8960, Val_Accuracy: 0.8933, Test_Accuracy: 0.9002
# Epoch 113/200, Train_Loss: 0.2569, Train_Accuracy: 0.8960, Val_Accuracy: 0.8934, Test_Accuracy: 0.9003
# Epoch 115/200, Train_Loss: 0.2559, Train_Accuracy: 0.8966, Val_Accuracy: 0.8936, Test_Accuracy: 0.9003
# Epoch 116/200, Train_Loss: 0.2555, Train_Accuracy: 0.8968, Val_Accuracy: 0.8938, Test_Accuracy: 0.9003
# Epoch 117/200, Train_Loss: 0.2550, Train_Accuracy: 0.8971, Val_Accuracy: 0.8941, Test_Accuracy: 0.9011
# Epoch 118/200, Train_Loss: 0.2545, Train_Accuracy: 0.8975, Val_Accuracy: 0.8947, Test_Accuracy: 0.9011
# Epoch 119/200, Train_Loss: 0.2540, Train_Accuracy: 0.8975, Val_Accuracy: 0.8950, Test_Accuracy: 0.9011
# Epoch 121/200, Train_Loss: 0.2530, Train_Accuracy: 0.8981, Val_Accuracy: 0.8953, Test_Accuracy: 0.9018
# Epoch 123/200, Train_Loss: 0.2520, Train_Accuracy: 0.8987, Val_Accuracy: 0.8959, Test_Accuracy: 0.9019
# Epoch 124/200, Train_Loss: 0.2515, Train_Accuracy: 0.8989, Val_Accuracy: 0.8961, Test_Accuracy: 0.9023
# Epoch 125/200, Train_Loss: 0.2510, Train_Accuracy: 0.8990, Val_Accuracy: 0.8963, Test_Accuracy: 0.9027
# Epoch 126/200, Train_Loss: 0.2505, Train_Accuracy: 0.8990, Val_Accuracy: 0.8966, Test_Accuracy: 0.9031
# Epoch 127/200, Train_Loss: 0.2500, Train_Accuracy: 0.8990, Val_Accuracy: 0.8970, Test_Accuracy: 0.9035
# Epoch 128/200, Train_Loss: 0.2496, Train_Accuracy: 0.8994, Val_Accuracy: 0.8973, Test_Accuracy: 0.9034
# Epoch 130/200, Train_Loss: 0.2486, Train_Accuracy: 0.8999, Val_Accuracy: 0.8978, Test_Accuracy: 0.9035
# Epoch 133/200, Train_Loss: 0.2471, Train_Accuracy: 0.9007, Val_Accuracy: 0.8981, Test_Accuracy: 0.9037
# Epoch 134/200, Train_Loss: 0.2467, Train_Accuracy: 0.9008, Val_Accuracy: 0.8985, Test_Accuracy: 0.9040
# Epoch 136/200, Train_Loss: 0.2457, Train_Accuracy: 0.9013, Val_Accuracy: 0.8991, Test_Accuracy: 0.9047
# Epoch 138/200, Train_Loss: 0.2448, Train_Accuracy: 0.9021, Val_Accuracy: 0.8996, Test_Accuracy: 0.9045
# Epoch 139/200, Train_Loss: 0.2443, Train_Accuracy: 0.9021, Val_Accuracy: 0.9003, Test_Accuracy: 0.9048
# Epoch 140/200, Train_Loss: 0.2438, Train_Accuracy: 0.9025, Val_Accuracy: 0.9005, Test_Accuracy: 0.9050
# Epoch 141/200, Train_Loss: 0.2433, Train_Accuracy: 0.9029, Val_Accuracy: 0.9010, Test_Accuracy: 0.9050
# Epoch 142/200, Train_Loss: 0.2428, Train_Accuracy: 0.9032, Val_Accuracy: 0.9012, Test_Accuracy: 0.9053
# Epoch 144/200, Train_Loss: 0.2418, Train_Accuracy: 0.9036, Val_Accuracy: 0.9014, Test_Accuracy: 0.9055
# Epoch 145/200, Train_Loss: 0.2414, Train_Accuracy: 0.9040, Val_Accuracy: 0.9019, Test_Accuracy: 0.9060
# Epoch 147/200, Train_Loss: 0.2404, Train_Accuracy: 0.9044, Val_Accuracy: 0.9025, Test_Accuracy: 0.9065
# Epoch 149/200, Train_Loss: 0.2394, Train_Accuracy: 0.9049, Val_Accuracy: 0.9027, Test_Accuracy: 0.9069
# Epoch 150/200, Train_Loss: 0.2390, Train_Accuracy: 0.9053, Val_Accuracy: 0.9029, Test_Accuracy: 0.9069
# Epoch 151/200, Train_Loss: 0.2385, Train_Accuracy: 0.9060, Val_Accuracy: 0.9030, Test_Accuracy: 0.9073
# Epoch 152/200, Train_Loss: 0.2380, Train_Accuracy: 0.9061, Val_Accuracy: 0.9031, Test_Accuracy: 0.9073
# Epoch 153/200, Train_Loss: 0.2375, Train_Accuracy: 0.9067, Val_Accuracy: 0.9032, Test_Accuracy: 0.9073
# Epoch 154/200, Train_Loss: 0.2370, Train_Accuracy: 0.9069, Val_Accuracy: 0.9035, Test_Accuracy: 0.9079
# Epoch 155/200, Train_Loss: 0.2365, Train_Accuracy: 0.9068, Val_Accuracy: 0.9041, Test_Accuracy: 0.9080
# Epoch 157/200, Train_Loss: 0.2356, Train_Accuracy: 0.9070, Val_Accuracy: 0.9044, Test_Accuracy: 0.9084
# Epoch 158/200, Train_Loss: 0.2351, Train_Accuracy: 0.9074, Val_Accuracy: 0.9048, Test_Accuracy: 0.9087
# Epoch 159/200, Train_Loss: 0.2346, Train_Accuracy: 0.9078, Val_Accuracy: 0.9051, Test_Accuracy: 0.9088
# Epoch 160/200, Train_Loss: 0.2341, Train_Accuracy: 0.9083, Val_Accuracy: 0.9057, Test_Accuracy: 0.9092
# Epoch 162/200, Train_Loss: 0.2331, Train_Accuracy: 0.9088, Val_Accuracy: 0.9060, Test_Accuracy: 0.9098
# Epoch 164/200, Train_Loss: 0.2322, Train_Accuracy: 0.9094, Val_Accuracy: 0.9061, Test_Accuracy: 0.9103
# Epoch 165/200, Train_Loss: 0.2317, Train_Accuracy: 0.9092, Val_Accuracy: 0.9066, Test_Accuracy: 0.9106
# Epoch 167/200, Train_Loss: 0.2307, Train_Accuracy: 0.9097, Val_Accuracy: 0.9071, Test_Accuracy: 0.9118
# Epoch 168/200, Train_Loss: 0.2302, Train_Accuracy: 0.9104, Val_Accuracy: 0.9075, Test_Accuracy: 0.9111
# Epoch 171/200, Train_Loss: 0.2288, Train_Accuracy: 0.9105, Val_Accuracy: 0.9078, Test_Accuracy: 0.9126
# Epoch 173/200, Train_Loss: 0.2278, Train_Accuracy: 0.9112, Val_Accuracy: 0.9083, Test_Accuracy: 0.9132
# Epoch 175/200, Train_Loss: 0.2269, Train_Accuracy: 0.9120, Val_Accuracy: 0.9084, Test_Accuracy: 0.9136
# Epoch 177/200, Train_Loss: 0.2258, Train_Accuracy: 0.9126, Val_Accuracy: 0.9088, Test_Accuracy: 0.9140
# Epoch 179/200, Train_Loss: 0.2246, Train_Accuracy: 0.9133, Val_Accuracy: 0.9090, Test_Accuracy: 0.9149
# Epoch 181/200, Train_Loss: 0.2236, Train_Accuracy: 0.9137, Val_Accuracy: 0.9095, Test_Accuracy: 0.9157
# Epoch 183/200, Train_Loss: 0.2228, Train_Accuracy: 0.9141, Val_Accuracy: 0.9098, Test_Accuracy: 0.9164
# Epoch 185/200, Train_Loss: 0.2235, Train_Accuracy: 0.9136, Val_Accuracy: 0.9115, Test_Accuracy: 0.9160
# Epoch 192/200, Train_Loss: 0.2206, Train_Accuracy: 0.9148, Val_Accuracy: 0.9117, Test_Accuracy: 0.9178
# Epoch 194/200, Train_Loss: 0.2213, Train_Accuracy: 0.9139, Val_Accuracy: 0.9126, Test_Accuracy: 0.9172
# Epoch 196/200, Train_Loss: 0.2166, Train_Accuracy: 0.9178, Val_Accuracy: 0.9132, Test_Accuracy: 0.9197
# Epoch 201/200, Train_Loss: 0.2158, Train_Accuracy: 0.9182, Val_Accuracy: 0.9143, Test_Accuracy: 0.9187

# %% [markdown]
# O modelo GNN simples foi baseado em GNN convolucional na estrutura PyTorch usando a extensão torch_geometric.
# Além disso, um próximo passo seria verificar outras camadas GNN que o torch_geometric oferece.
